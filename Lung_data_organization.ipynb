# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
from pathlib import Path

# %%
path = Path('/nfs2/NLST/NIfTI')

# %%
path.resolve()
# Out:
# PosixPath('/nfs2/NLST/NIfTI')

# %%
df = pd.read_csv('/nfs2/NLST/NIfTI/T0_all.csv')

# %%
df.columns
# Out:
# Index(['pid', 'manufacture', 'model_name', 'convolution_kernel',
#        'slice_thickness', 'nii_file', 'png_file', 'voxel_size_x',
#        'voxel_size_y', 'voxel_size_z', 'num_img_dimension', 'num_dcm',
#        'orient', 'series_uid', 'record_retrieval_failed', 'time_point'],
#       dtype='object')

# %%
df
# Out:
#           pid         manufacture       model_name convolution_kernel  \
# 0      130694  GE MEDICAL SYSTEMS  LightSpeed QX/i      EXPERIMENTAL7
# 1      130694  GE MEDICAL SYSTEMS  LightSpeed QX/i           STANDARD
# 2      134532  GE MEDICAL SYSTEMS     HiSpeed QX/i      EXPERIMENTAL7
# 3      134532  GE MEDICAL SYSTEMS     HiSpeed QX/i               BONE
# 4      134532  GE MEDICAL SYSTEMS     HiSpeed QX/i           STANDARD
# ...       ...                 ...              ...                ...
# 69901  205219             TOSHIBA         Aquilion               FL01
# 69902  205219             TOSHIBA         Aquilion               FC51
# 69903  131515  GE MEDICAL SYSTEMS     HiSpeed QX/i           STANDARD
# 69904  131515  GE MEDICAL SYSTEMS     HiSpeed QX/i               BONE
# 69905  131515  GE MEDICAL SYSTEMS     HiSpeed QX/i      EXPERIMENTAL7
#
#        slice_thickness  nii_file  png_file  voxel_size_x  voxel_size_y  \
# 0           358.727264         1         1      0.596847      0.545455
# 1             2.500000         1         1      0.644531      0.644531
# 2           460.181793         1         1      0.596847      0.545455
# 3             2.500000         1         1      0.703125      0.703125
# 4             2.500000         1         1      0.703125      0.703125
# ...                ...       ...       ...           ...           ...
# 69901         2.000000         0         0           NaN           NaN
# 69902         2.000000         1         1      0.743000      0.743000
# 69903         2.500000         1         1      0.664062      0.664062
# 69904         2.500000         1         1      0.664062      0.664062
# 69905       460.181793         1         1      0.596847      0.545455
#
#        voxel_size_z  num_img_dimension  num_dcm orient  \
# 0        265.000000                3.0        2    ASL
# 1          2.000000                3.0      150    LAS
# 2        265.000000                3.0        2    ASL
# 3          2.500000                3.0      137    LAS
# 4          2.500000                3.0      137    LAS
# ...             ...                ...      ...    ...
# 69901           NaN                NaN        1    NaN
# 69902      1.699951                3.0      194    LAS
# 69903      2.500000                3.0      138    LAS
# 69904      2.500000                3.0      138    LAS
# 69905    265.000000                3.0        2    ASL
#
#                                               series_uid  \
# 0      1.2.840.113654.2.55.20894722146381782923403247...
# 1      1.2.840.113654.2.55.12730625245910917329262333...
# 2      1.2.840.113654.2.55.19775853905673308355525811...
# 3      1.2.840.113654.2.55.60126924226029595678182467...
# 4      1.2.840.113654.2.55.17876359784670337597334889...
# ...                                                  ...
# 69901  1.3.6.1.4.1.14519.5.2.1.7009.9004.270279400844...
# 69902  1.3.6.1.4.1.14519.5.2.1.7009.9004.150045947460...
# 69903  1.2.840.113654.2.55.34818673837865089145662278...
# 69904  1.2.840.113654.2.55.18333105177928074785593996...
# 69905  1.2.840.113654.2.55.13775867707849331139387903...
#
#        record_retrieval_failed time_point
# 0                          NaN         T0
# 1                          NaN         T0
# 2                          NaN         T0
# 3                          NaN         T0
# 4                          NaN         T0
# ...                        ...        ...
# 69901                      NaN         T0
# 69902                      NaN         T0
# 69903                      NaN         T0
# 69904                      NaN         T0
# 69905                      NaN         T0
#
# [69906 rows x 16 columns]

# %%
df = pd.read_csv('/nfs/masi/MCL/file/clinical/LabelFile/20210615MK/20210615_nopassword.csv')

# %%
df
# Out:
#       Patient.ID         MRN       MCL.ID Patient.ID.1 Sample.Barcode   QC  \
# 0      376873159         NaN    376873159    376873159        02898-6  NaN
# 1      398957338         NaN    398957338    398957338       2011-636  NaN
# 2     1759365513         NaN   1759365513   1759365513       2010-578  NaN
# 3     2368954232         NaN   2368954232   2368954232       2012-649  NaN
# 4     2962357115         NaN   2962357115   2962357115       2012-666  NaN
# ...          ...         ...          ...          ...            ...  ...
# 1194        7813  31351380.0  40055232242         7813            120  NaN
# 1195        7169  29216553.0  41485791537         7169         511759  NaN
# 1196        4265  21058391.0  41516003600         4265        R005778  NaN
# 1197        7815  32748493.0  42432563357         7815            121  NaN
# 1198        8800  33993908.0  42908929509         8800         533668  NaN
#
#                                Changelog & Notes Sub.Cohort  \
# 0                                            NaN       upmc
# 1                                            NaN       upmc
# 2                                            NaN       upmc
# 3                                            NaN       upmc
# 4                                            NaN       upmc
# ...                                          ...        ...
# 1194                                         NaN        V-I
# 1195                                         NaN        V-I
# 1196                                         NaN        V-I
# 1197                                         NaN        V-I
# 1198  2019.08.15 Excluded, blood draw post chemo        V-I
#
#      Cohort.1.Vandy.2.UPMC.3.DECAMP.4.UCD  Has.Cyfra  ...  CYF/TV  HM  \
# 0                                       2          1  ...     NaN NaN
# 1                                       2          1  ...     NaN NaN
# 2                                       2          1  ...     NaN NaN
# 3                                       2          1  ...     NaN NaN
# 4                                       2          1  ...     NaN NaN
# ...                                   ...        ...  ...     ...  ..
# 1194                                    1          1  ...     NaN NaN
# 1195                                    1          1  ...     NaN NaN
# 1196                                    1          1  ...     NaN NaN
# 1197                                    1          1  ...     NaN NaN
# 1198                                    1          1  ...     NaN NaN
#
#             MRN.1  ANTPOST_LENGTH_MM  SURFACE_AREA_TO_VOLUME_RATIO_MM  \
# 0       376873159          20.495274                        0.3892586
# 1       398957338          3.8083737                        1.5481585
# 2      1759365513           24.47374                       0.33766484
# 3      2368954232          23.754082                       0.35110658
# 4      2962357115          6.3351707                         1.257702
# ...           ...                ...                              ...
# 1194  40055232242           15.96421                       0.46146473
# 1195  41485791537           35.61059                       0.28502083
# 1196  41516003600           73.82753                       0.21033387
# 1197  42432563357           14.24832                        0.5977823
# 1198  42908929509          54.502243                       0.23136589
#
#       SURFACE_AREA_MM2  has_blood  BMayoBrock    more_MCLID       MCL_ID
# 0           1341.84130        1.0         1.0           NaN    376873159
# 1             52.92767        1.0         1.0           NaN    398957338
# 2           1303.55870        1.0         1.0           NaN   1759365513
# 3           1751.79050        1.0         1.0           NaN   2368954232
# 4             90.94758        1.0         1.0           NaN   2962357115
# ...                ...        ...         ...           ...          ...
# 1194         624.46760        1.0         1.0  4.005523e+10  40055232242
# 1195        3149.71140        1.0         1.0  4.148579e+10  41485791537
# 1196       21325.37300        1.0         1.0  4.151600e+10  41516003600
# 1197         996.26030        1.0         1.0  4.243256e+10  42432563357
# 1198        7454.21500        1.0         1.0  4.290893e+10  42908929509
#
# [1199 rows x 102 columns]

# %%
Ids = df['MCL.ID']

# %%
ID = pd.Series(Ids)

# %%
sc = df['Sub.Cohort']

# %%
sc.unique()
# Out:
# array(['upmc', 'DECAMP-1', 'UC.Denver', 'V-0', 'V-II', 'mayo', 'Abbott.2',
#        nan, 'V-I', ' 2020-04-27 Updated MCL ID'], dtype=object)

# %%
pid = df['Patient.ID']

# %%
pid.unique()
# Out:
# array(['376873159', '398957338', '1759365513', ..., '4265', '7815',
#        '8800'], dtype=object)
